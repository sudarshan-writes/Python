# %% [markdown]
# # Relational Operator

# %% [markdown]
# * Compares the Data
# * Returns the Boolean

# %% [raw]
# <  - Less Than
# >  - Greater Than
# <= - Less Than or Equal to
# >= - Greater Than or Equal to
# == - Equal to
# != - Not Equal to
#
# <= & >=
# only for this parameter it splits into two and checks the condtion.
# <= splits as '< and =' and checks.
# >= splits as '> and =' and checks.

# %%
a = 20
b = 30
a < b
# Out:
# True

# %%
a = 30
b = 20
a < b
# Out:
# False

# %%
a = 20
b = 30
a > b
# Out:
# False

# %%
a = 30
b = 20
a > b
# Out:
# True

# %%
a = 20
b = 30
a <= b
# Out:
# True

# %%
a = 20
b = 40
a <= b
# Out:
# True

# %%
a = 20
b = 30
a >= b
# Out:
# False

# %%
a = 20
b = 40
a >= b
# Out:
# False

# %%
a = 20
b = 30
a == b
# Out:
# False

# %%
a = 30
b = 30
a == b
# Out:
# True

# %%
a = 20
b = 30
a != b
# Out:
# True

# %%
a = 30
b = 30
a != b
# Out:
# False

# %% [markdown]
# ### Let's Try using String data

# %%
a = 'Hello'
b = 'Innomatics'
a < b
# Out:
# True

# %%
ord('H')# To know the ascii value
# Out:
# 72

# %%
ord('I')
# Out:
# 73

# %% [markdown]
# ### Reason
# **Internally it compares 'H' & 'I' with ascii value**
#
# H(72) < I(73)
#
# 'True'
#
# **If both ascii values are equal it will compare next letter/character**
#
# Internally with path of strings we are comparing with numericals only

# %%
a = 'Hello'
b = 'hello'
a < b
#case sensitive
# Out:
# True

# %%
ord('H')
# Out:
# 72

# %%
ord('h')
# Out:
# 104

# %%
a = 'hello'
b = 'hello'
a == b
# Out:
# True

# %%
a = 'hello'
b = 'hello '
a == b
# space is also a character in python
# Out:
# False

# %%
a = 'hello'
b = 'hello '
a != b
# Out:
# True

# %% [markdown]
# ### Important functions

# %%
print('hello') # To display the output

# %%
ord('h') # To know the ascii value
# Out:
# 104

# %%
a = 20
id(a) # To know the address of data

# In this memory location - 140734706132488 this [a = 20]value is preserved
# Out:
# 140734706132488

# %%
x = 'hello'
id(x) # To know the address of data

# In this memory location - 2173562931600 this string value is preserved
# Out:
# 2173562931600

# %%
name = 'Sudarshan'
len(name) # frequency of letters in string
# you can't apply this len() function to numerical data
# Out:
# 9

# %%
a = 34.5
type(a) # returns type of data
# Out:
# float

# %%
name = 'Sudarshan'
type(name)
# Out:
# str

# %%
first_name = input('Enter your first name')
last_name = input('Enter your last name')
print(first_name +  last_name )
# Out:
# Enter your first name Narendra
# Enter your last name modi
# Narendramodi

# %%
a = input('Enter your first num')
b = input('Enter your last num')
print(a+b )
#here comes the problem as it is in string format it is combining together.
# Out:
# Enter your first num 2
# Enter your last num 3
# 23

# %% [markdown]
# so we use **int()** integer function allows only **Integer**

# %%
a = int(input('Enter your first num'))
b = int(input('Enter your last num'))
print(a+b )
# it makes the difference
# Out:
# Enter your first num 2
# Enter your last num 3
# 5

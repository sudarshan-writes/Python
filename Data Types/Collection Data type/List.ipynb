# %% [markdown]
# ## Representation

# %%
marks = [78,86,52,84,63]
marks2 = list((78,86,52,84,63))

# %%
type(marks)
# Out:
# list

# %%
type(marks2)
# Out:
# list

# %%
#creating a empty list
list1 = ()
list2 = list()

# %% [markdown]
# ## Operations of list

# %%
marks = [78,86,52,84,63]

# %%
len(marks)
# Out:
# 5

# %%
type(marks)
# Out:
# list

# %%
ord(marks)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 ord(marks)
#
# TypeError: ord() expected string of length 1, but list found

# %%
marks[-1]
# Out:
# 63

# %%
min(marks)
# Out:
# 52

# %%
max(marks)
# Out:
# 86

# %%
sum(marks)
# Out:
# 363

# %% [markdown]
# `Apply all operators concept`

# %%
a = [10,20,30,40,50]
b = [15,25,35,45,55,60,65]

# %%
a+b
# Out:
# [10, 20, 30, 40, 50, 15, 25, 35, 45, 55, 60, 65]

# %%
a-b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 a-b
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
a*b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 a*b
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
a/b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 a/b
#
# TypeError: unsupported operand type(s) for /: 'list' and 'list'

# %%
a//b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 a//b
#
# TypeError: unsupported operand type(s) for //: 'list' and 'list'

# %%
a%b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 a%b
#
# TypeError: unsupported operand type(s) for %: 'list' and 'list'

# %%
a*2
# Out:
# [10, 20, 30, 40, 50, 10, 20, 30, 40, 50]

# %%
b*2
# Out:
# [15, 25, 35, 45, 55, 60, 65, 15, 25, 35, 45, 55, 60, 65]

# %% [markdown]
# ## Attributes/ characteristics

# %% [markdown]
# ## 1. Mutable

# %%
a = [10,20,30,40,50]

# %%
a.append(60)

# %%
a
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
a.remove(20)

# %%
a
# Out:
# [10, 30, 40, 50, 60]

# %% [markdown]
# ## 2.Ordered - Follows Sequence

# %%
fruits = ['apple','banana','orange']

# %%
fruits[-1]
# Out:
# 'orange'

# %% [markdown]
# ## 3.Duplicates are Allowed

# %%
marks = [10, 20, 30, 10, 40, 50, 20, 30, 40, 50]

# %% [markdown]
# ## 4. Index - Follows

# %%
marks[3]
# Out:
# 10

# %%
marks[5::2]
# Out:
# [50, 30, 50]

# %% [markdown]
# ## List methods

# %%
marks = [34,65,85,32,52]

# %% [markdown]
# `To Add Data`

# %%
marks.append(99) # To add single element at the end of the list

# %%
marks.extend([54,25,34,12,10,2,2,1,3]) #To add more than one element at the end of the list

# %%
marks
# Out:
# [34, 65, 85, 32, 52, 99, 54, 25, 34, 12, 10, 2, 2, 1, 3]

# %%
marks.insert(0,100) #To add the element at position/index

# %%
marks
# Out:
# [100, 34, 65, 85, 32, 52, 99, 54, 25, 34, 12, 10, 2, 2, 1, 3]

# %% [markdown]
# `To Remove Data`

# %%
marks = [34,65,85,32,52]

# %%
marks.remove(52) #value based

# %%
marks
# Out:
# [34, 65, 85, 32, 52]

# %%
marks.pop() #Index based removal--by default from last
# Out:
# 52

# %%
marks
# Out:
# [34, 65, 85, 32]

# %%
marks.pop(1)
# Out:
# 65

# %%
marks
# Out:
# [34, 85, 32]

# %%
marks.clear() # removes all the values and returns to empty list

# %%
marks
# Out:
# []

# %%
marks =  [34,65,85,32,52]
del marks

# %%
marks
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 marks
#
# NameError: name 'marks' is not defined

# %% [markdown]
# ## Searching & Sorting

# %%
marks =  [34,65,85,32,52,32]

# %%
marks.index(52) # to know index of value
# Out:
# 4

# %%
marks.reverse()

# %%
marks
# Out:
# [32, 52, 32, 85, 65, 34]

# %%
a = ['Sudarshan',"AAdi"]

# %%
a.reverse()

# %%
a
# Out:
# ['AAdi', 'Sudarshan']

# %%
marks =  [34,65,85,32,52,32]
marks.sort()
marks
# Out:
# [32, 32, 34, 52, 65, 85]

# %%
marks =  [34,65,85,32,52,32]
marks.sort(reverse=True)
marks
# Out:
# [85, 65, 52, 34, 32, 32]

# %%
fruits = ['banana','orange','apple','sapota','sapota']
fruits.sort()
fruits
# Out:
# ['apple', 'banana', 'orange', 'sapota', 'sapota']

# %%
marks =  [34,65,85,32,52,32]
marks.count(32) # To know number of occurrences of value
# Out:
# 2

# %%
marks.count(34)
# Out:
# 1

# %%
marks =  [34,65,85,32,52,32]
marks1 = marks.copy()

# %%
marks1.append(100)

# %%
marks1
# Out:
# [34, 65, 85, 32, 52, 32, 100]

# %%
marks
# Out:
# [34, 65, 85, 32, 52, 32]

# %% [markdown]
# ## Representation

# %%
marks = (78,86,52,84,63)
marks2 = tuple((78,86,52,84,63))

# %%
type(marks)
# Out:
# tuple

# %%
type(marks2)
# Out:
# tuple

# %%
tuple1 = ('monday','tuesday','wednesday','thursday','friday','saturday')

# %%
type(tuple1)
# Out:
# tuple

# %%
days = tuple(('monday','tuesday','wednesday','thursday','friday','saturday'))
days
# Out:
# ('monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday')

# %%
type(days)
# Out:
# tuple

# %%
#creating a empty tuple
tup1 = ()
tup2 = tuple()

# %% [markdown]
# ## List vs Tuple

# %%
# %%time
list1 = [i for i in range(1,1000000)]
# Out:
# CPU times: total: 93.8 ms
# Wall time: 94.4 ms

# %%
# %%time
tup1 = (i for i in range(1,1000000))
# Out:
# CPU times: total: 0 ns
# Wall time: 16 μs

# %%
import sys

# %%
sys.getsizeof(list1)
# Out:
# 8448728

# %%
sys.getsizeof(tup1)
# Out:
# 192

# %% [markdown]
# ## Attributes

# %% [markdown]
# ### 1. Immutable

# %%
names = ('mahesh','suresh','ramesh' )

# %%
names.append('pullesh')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 names.append('pullesh')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# **Not only append any methods are not performable due it immutability**

# %% [markdown]
# ### 2.Ordered

# %%
names
# Out:
# ('mahesh', 'suresh', 'ramesh')

# %% [markdown]
# ### 3. Duplicates are allowed

# %%
names = ('mahesh','suresh','ramesh','mahesh')
names
# Out:
# ('mahesh', 'suresh', 'ramesh', 'mahesh')

# %% [markdown]
# ### 4.Index

# %%
names[3]
# Out:
# 'mahesh'

# %% [markdown]
# ## Tuple methods

# %%
marks = (45,65,84,62,85,32,41,63,75,0,16,3,7)

# %%
marks.count(84)
# Out:
# 1

# %%
marks.index(32)
# Out:
# 5

# %% [markdown]
# ### Nested lists / Tuples

# %%
list2 =[2,3,4,['Rajesh','suresh'],3,4]

# %%
list2[3][0]
# Out:
# 'Rajesh'

# %%
list3 = [2,3,4,['Rajesh','Naresh'],3,4,['sun','mon',["january","february"]]]

# %%
len(list3)
# Out:
# 7

# %%
list3[6][2][0]
# Out:
# 'january'

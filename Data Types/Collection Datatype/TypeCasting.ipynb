# %%
student_data = []
name = input('Enter your name ::')
age = int(input('enter your age ::'))
phone = int(input('enter your phone number ::'))
student_data.extend([name,age,phone])
student_data
# Out:
# Enter your name :: sudarshan
# enter your age :: 22
# enter your phone number :: 9874563210
# ['sudarshan', 22, 9874563210]

# %%
type(phone)
# Out:
# int

# %%
len(phone)# cannot be applied on int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 len(phone)
#
# TypeError: object of type 'int' has no len()

# %%
phone.startswith(6)# cannot be applied on int
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 phone.startswith(6)
#
# AttributeError: 'int' object has no attribute 'startswith'

# %%
phone = int(input('enter your phone number ::'))
str_phone = str(phone)
# Out:
# enter your phone number :: 8247555926

# %%
len(str_phone) == 10
# Out:
# True

# %%
str_phone.startswith(('6','7','8','9'))
# Out:
# True

# %%
a = 12345
int(str(a)[::-1])
# Out:
# 54321

# %%
l1 = [101,102,103,101,104,105]
l1
# Out:
# [101, 102, 103, 101, 104, 105]

# %%
set(l1)
# Out:
# {101, 102, 103, 104, 105}

# %%
num1 = 12345
num2 = 67890

# %%
int(str(num1) + str(num2))
# Out:
# 1234567890

# %%
bool(1020)
# Out:
# True

# %%
#i dont need duplicates
list1 = [10,20,30,40,50,10,20,30,40,50]

# %%
list(set(list1))
# Out:
# [40, 10, 50, 20, 30]

# %%
tuple(set(list1))
# Out:
# (40, 10, 50, 20, 30)

# %%
a = 2.5
b = 3.73 
c = a*b
c
# Out:
# 9.325

# %%
print(round(c,1))
print(round(c,2))
print(round(c,3))
# Out:
# 9.3
# 9.32
# 9.325

# %%
a = 2.5
b = 3.73 
c = a*b

# ** print(f"The output is {c:.nf}") **

print(f"The output is {c:.1f}")
print(f"The output is {c:.2f}")
print(f"The output is {c:.3f}")
# Out:
# The output is 9.3
# The output is 9.32
# The output is 9.325
